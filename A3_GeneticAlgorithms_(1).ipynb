# %% [markdown]
# <a href="https://colab.research.google.com/github/enzomaeda1/Computacao-Paralela/blob/main/A3_GeneticAlgorithms_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="http://meusite.mackenzie.br/rogerio/mackenzie_logo/UPM.2_horizontal_vermelho.jpg"  width=300, align="right">
# <br>
# <br>
# <br>
# <br>
# <br>
#
# # **Algoritmos Genéticos**
# ---

# %%
#@title **Identificação do Grupo**

#@markdown Integrantes do Grupo, nome completo em orgem alfabética (*informe \<RA\>,\<nome\>*)
Aluno1 = '10364987, Enzo Ryo Maeda Kanbayashi' #@param {type:"string"}
Aluno2 = 'None' #@param {type:"string"}
Aluno3 = 'None' #@param {type:"string"}
Aluno4 = 'None' #@param {type:"string"}
Aluno5 = 'None' #@param {type:"string"}

# %%
#@title **Escolha a opção de Exercício Selecionado**
Exercicio_selecionado = "Exercício A. Otimização multi-objetivo" #@param ["Exercício A. Otimização multi-objetivo", "Exercício B. Forca"]

# %% [markdown]
# # **Resumo**
#
# **.

# %% [markdown]
# # **Descrição da Solução**
#
# *Discuta aqui os principais aspectos da solução desenvolvida*.
#
# - Para a opção *Exercício A. Otimização multi-objetivo*, isso envolve descrever o cenário fictício do problema de otimização e são construídas as funções objetivo.
#
# - Para a opção *Exercício B. Força*, isso envolve descrever resumidamente em tópicos como é construído o seu algoritmo genético para cada uma das etapas (representação das soluções em genes, função de fitness, crossover, mutação e seleção), ou, no caso de empregar o PyGDA, descrever a modelagem empregada.

# %% [markdown]
# # **Implementação**
#
# *Aqui o código da sua solução. Você deve explicar em linhas gerais o código. Para isso você pode quebrar o código em algumas partes e incluir células de texto explicativos. Não empregue para isso comentários no corpo do código, mas crie células de texto do notebook.*
#
# > ***ATENÇÃO: O código deve ser 100% executável no Colab e, portanto, não devem ser empregados arquivos locais (da sua máquina) e, se necessário, devem ser incluídos o install de novas bibliotecas empregadas.***

# %% [markdown]
# #Instalação do Pygad

# %%
# !pip install pygad
# Out:
# Collecting pygad
#   Downloading pygad-3.4.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from pygad) (3.1.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from pygad) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pygad) (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygad) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygad) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygad) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygad) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygad) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygad) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygad) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygad) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->pygad) (1.17.0)
# Downloading pygad-3.4.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: pygad
# Successfully installed pygad-3.4.0

# %% [markdown]
# #Código do programa

# %%
# Seus Códigos aqui intercalados de células de texto com comentários

import pygad
import numpy as np

# Salário dos funcionários em diferentes faixas
fatores = {
    "salario1": 1000,
    "salario2": 2000,
    "salario3": 3000,
    "salario4": 4000,
    "salario5": 5000
}

# Lista de valores dos fatores
function_inputs = np.array(list(fatores.values()))
# Orçamento máximo
orcamento_maximo = 200000  # Pode ser ajustado conforme o caso real
# Quantidade desejada de funcionários
quantidade_desejada = 100

# Função que mede a quantidade de funcionarios e o orçamento máximo
def fitness_func(ga_instance, solution, solution_idx):
    total_funcionarios = np.sum(solution)
    total_custo = np.sum(solution * function_inputs)

    if total_custo > orcamento_maximo:
        return 0  # Penaliza soluções que ultrapassam o orçamento

    if total_funcionarios > quantidade_desejada:
        return 0  # Penaliza soluções que ultrapassam quantidade de funcionarios

    fitness = total_funcionarios / quantidade_desejada  # Maximiza o número de funcionários
    return fitness

num_generations = 200  # Número de gerações
num_parents_mating = 10  # Quantidade de pais selecionados

sol_per_pop = 20  # Tamanho da população
num_genes = len(function_inputs)

def on_generation(ga_instance):
    print(f"Geração: {ga_instance.generations_completed}")
    print(f"Melhor Fitness: {ga_instance.best_solution()[1]}")




# Configuração do Algoritmo Genético
ga_instance = pygad.GA(
    num_generations=num_generations,
    num_parents_mating=num_parents_mating,
    sol_per_pop=sol_per_pop,
    num_genes=num_genes,
    fitness_func=fitness_func,
    on_generation=on_generation,
    init_range_low=0,
    init_range_high=100,
    gene_type = int
)

# %% [markdown]
# # **Resultados (Testes)**
#
# *Faça aqui no mínimo 4 simulações para diferentes configuraçõoes do seu problema, que mostrem a efetividade da sua solução. Você pode começar com problemas menores e crescer a complexidade a medida que avança nos problemas. Apresente a solução e o gráfico de convergência da solução ao longo das gerações. Comente em células de texto explicativas os testes e os seus resultados.*

# %% [markdown]
# #Teste 1
#
# *   Orçamento máximo 200000
# *   Máximo de funcionarios desejados 100
#
# #Teste 2
#
# *   Orçamento máximo 400000
# *   Máximo de funcionarios desejados 200
#
# #Teste 3
#
# *   Orçamento máximo 100000
# *   Máximo de funcionarios desejados 50
#
# #Teste 4
#
# *   Orçamento máximo 50000
# *   Máximo de funcionarios desejados 10

# %%
# Seus Códigos aqui intercalados de células de texto com comentários

# Executa o algoritmo
ga_instance.run()
ga_instance.plot_fitness()

# Exibe os melhores resultados
solution, solution_fitness, solution_idx = ga_instance.best_solution()
print(f"Quantidade de funcionários por faixa salarial: {solution}")
print(f"Fitness da melhor solução: {solution_fitness}")

total_funcionarios = np.sum(solution)
total_custo = np.sum(solution * function_inputs)
print(f"Número total de funcionários contratados: {int(total_funcionarios)}")
print(f"Custo total da folha de pagamento: {total_custo}")
# Out:
# Geração: 1
# Melhor Fitness: 0
# Geração: 2
# Melhor Fitness: 0
# Geração: 3
# Melhor Fitness: 0
# Geração: 4
# Melhor Fitness: 0
# Geração: 5
# Melhor Fitness: 0
# Geração: 6
# Melhor Fitness: 0
# Geração: 7
# Melhor Fitness: 0
# Geração: 8
# Melhor Fitness: 0
# Geração: 9
# Melhor Fitness: 0
# Geração: 10
# Melhor Fitness: 0
# Geração: 11
# Melhor Fitness: 0
# Geração: 12
# Melhor Fitness: 0
# Geração: 13
# Melhor Fitness: 0
# Geração: 14
# Melhor Fitness: 0
# Geração: 15
# Melhor Fitness: 0
# Geração: 16
# Melhor Fitness: 0
# Geração: 17
# Melhor Fitness: 0
# Geração: 18
# Melhor Fitness: 0
# Geração: 19
# Melhor Fitness: 0
# Geração: 20
# Melhor Fitness: 0
# Geração: 21
# Melhor Fitness: 0
# Geração: 22
# Melhor Fitness: 0
# Geração: 23
# Melhor Fitness: 0
# Geração: 24
# Melhor Fitness: 0
# Geração: 25
# Melhor Fitness: 0
# Geração: 26
# Melhor Fitness: 0
# Geração: 27
# Melhor Fitness: 0
# Geração: 28
# Melhor Fitness: 0
# Geração: 29
# Melhor Fitness: 0
# Geração: 30
# Melhor Fitness: 0
# Geração: 31
# Melhor Fitness: 0
# Geração: 32
# Melhor Fitness: 0
# Geração: 33
# Melhor Fitness: 0
# Geração: 34
# Melhor Fitness: 0
# Geração: 35
# Melhor Fitness: 0
# Geração: 36
# Melhor Fitness: 0
# Geração: 37
# Melhor Fitness: 0
# Geração: 38
# Melhor Fitness: 0
# Geração: 39
# Melhor Fitness: 1.0
# Geração: 179
# Melhor Fitness: 1.0
# Geração: 180
# Melhor Fitness: 1.0
# Geração: 181
# Melhor Fitness: 1.0
# Geração: 182
# Melhor Fitness: 1.0
# Geração: 183
# Melhor Fitness: 1.0
# Geração: 184
# Melhor Fitness: 1.0
# Geração: 185
# Melhor Fitness: 1.0
# Geração: 186
# Melhor Fitness: 1.0
# Geração: 187
# Melhor Fitness: 1.0
# Geração: 188
# Melhor Fitness: 1.0
# Geração: 189
# Melhor Fitness: 1.0
# Geração: 190
# Melhor Fitness: 1.0
# Geração: 191
# Melhor Fitness: 1.0
# Geração: 192
# Melhor Fitness: 1.0
# Geração: 193
# Melhor Fitness: 1.0
# Geração: 194
# Melhor Fitness: 1.0
# Geração: 195
# Melhor Fitness: 1.0
# Geração: 196
# Melhor Fitness: 1.0
# Geração: 197
# Melhor Fitness: 1.0
# Geração: 198
# Melhor Fitness: 1.0
# Geração: 199
# Melhor Fitness: 1.0
# Geração: 200
# Melhor Fitness: 1.0
# Quantidade de funcionários por faixa salarial: [77  0  0 21  2]
# Fitness da melhor solução: 1.0
# Número total de funcionários contratados: 100
# Custo total da folha de pagamento: 171000

# %%
# Salário dos funcionários em diferentes faixas
fatores = {
    "salario1": 1000,
    "salario2": 2000,
    "salario3": 3000,
    "salario4": 4000,
    "salario5": 5000
}

# Lista de valores dos fatores
function_inputs = np.array(list(fatores.values()))
# Orçamento máximo
orcamento_maximo = 400000  # Pode ser ajustado conforme o caso real
# Quantidade desejada de funcionários
quantidade_desejada = 200

# Função que mede a quantidade de funcionarios e o orçamento máximo
def fitness_func(ga_instance, solution, solution_idx):
    total_funcionarios = np.sum(solution)
    total_custo = np.sum(solution * function_inputs)

    if total_custo > orcamento_maximo:
        return 0  # Penaliza soluções que ultrapassam o orçamento

    if total_funcionarios > quantidade_desejada:
        return 0  # Penaliza soluções que ultrapassam quantidade de funcionarios

    fitness = total_funcionarios / quantidade_desejada  # Maximiza o número de funcionários
    return fitness

num_generations = 200  # Número de gerações
num_parents_mating = 10  # Quantidade de pais selecionados

sol_per_pop = 20  # Tamanho da população
num_genes = len(function_inputs)

def on_generation(ga_instance):
    print(f"Geração: {ga_instance.generations_completed}")
    print(f"Melhor Fitness: {ga_instance.best_solution()[1]}")


# Configuração do Algoritmo Genético
ga_instance = pygad.GA(
    num_generations=num_generations,
    num_parents_mating=num_parents_mating,
    sol_per_pop=sol_per_pop,
    num_genes=num_genes,
    fitness_func=fitness_func,
    on_generation=on_generation,
    init_range_low=0,
    init_range_high=100,
    gene_type = int
)


# Executa o algoritmo
ga_instance.run()
ga_instance.plot_fitness()

# Exibe os melhores resultados
solution, solution_fitness, solution_idx = ga_instance.best_solution()
print(f"Quantidade de funcionários por faixa salarial: {solution}")
print(f"Fitness da melhor solução: {solution_fitness}")

total_funcionarios = np.sum(solution)
total_custo = np.sum(solution * function_inputs)
print(f"Número total de funcionários contratados: {int(total_funcionarios)}")
print(f"Custo total da folha de pagamento: {total_custo}")
# Out:
# Geração: 1
# Melhor Fitness: 0.665
# Geração: 2
# Melhor Fitness: 0.665
# Geração: 3
    "salario3": 3000,
    "salario4": 4000,
    "salario5": 5000
}

# Lista de valores dos fatores
function_inputs = np.array(list(fatores.values()))
# Orçamento máximo
orcamento_maximo = 100000  # Pode ser ajustado conforme o caso real
# Quantidade desejada de funcionários
quantidade_desejada = 50

# Função que mede a quantidade de funcionarios e o orçamento máximo
def fitness_func(ga_instance, solution, solution_idx):
    total_funcionarios = np.sum(solution)
    total_custo = np.sum(solution * function_inputs)

    if total_custo > orcamento_maximo:
        return 0  # Penaliza soluções que ultrapassam o orçamento

    if total_funcionarios > quantidade_desejada:
        return 0  # Penaliza soluções que ultrapassam quantidade de funcionarios

    fitness = total_funcionarios / quantidade_desejada  # Maximiza o número de funcionários
    return fitness

num_generations = 200  # Número de gerações
num_parents_mating = 10  # Quantidade de pais selecionados

sol_per_pop = 20  # Tamanho da população
num_genes = len(function_inputs)

def on_generation(ga_instance):
    print(f"Geração: {ga_instance.generations_completed}")
    print(f"Melhor Fitness: {ga_instance.best_solution()[1]}")


# Configuração do Algoritmo Genético
ga_instance = pygad.GA(
    num_generations=num_generations,
    num_parents_mating=num_parents_mating,
    sol_per_pop=sol_per_pop,
    num_genes=num_genes,
    fitness_func=fitness_func,
    on_generation=on_generation,
    init_range_low=0,
    init_range_high=100,
    gene_type = int
)


# Executa o algoritmo
ga_instance.run()
ga_instance.plot_fitness()

# Exibe os melhores resultados
solution, solution_fitness, solution_idx = ga_instance.best_solution()
print(f"Quantidade de funcionários por faixa salarial: {solution}")
print(f"Fitness da melhor solução: {solution_fitness}")

total_funcionarios = np.sum(solution)
total_custo = np.sum(solution * function_inputs)
print(f"Número total de funcionários contratados: {int(total_funcionarios)}")
print(f"Custo total da folha de pagamento: {total_custo}")
# Out:
# Geração: 1
# Melhor Fitness: 0
# Geração: 2
# Melhor Fitness: 0
# Geração: 3
# Melhor Fitness: 0
# Geração: 4
# Melhor Fitness: 0
# Geração: 5
# Melhor Fitness: 0
# Geração: 6
# Melhor Fitness: 0
# Geração: 7
# Melhor Fitness: 0
# Geração: 8
# Melhor Fitness: 0
# Geração: 9
# Melhor Fitness: 0
# Geração: 10
# Melhor Fitness: 0
# Geração: 11
# Melhor Fitness: 0
# Geração: 12
# Melhor Fitness: 0
# Geração: 13
# Melhor Fitness: 0
# Geração: 14
# Melhor Fitness: 0
# Geração: 15
# Melhor Fitness: 0
# Geração: 16
# Melhor Fitness: 0
# Geração: 17
# Melhor Fitness: 0
# Geração: 18
# Melhor Fitness: 0
# Geração: 19
# Melhor Fitness: 0
# Geração: 20
# Melhor Fitness: 0
# Geração: 21
# Melhor Fitness: 0
# Geração: 22
# Melhor Fitness: 0
# Geração: 23
# Melhor Fitness: 0
# Geração: 24
# Melhor Fitness: 0
# Geração: 25
# Melhor Fitness: 0
# Geração: 26
# Melhor Fitness: 0
# Geração: 27
# Melhor Fitness: 0
# Geração: 28
# Melhor Fitness: 0
# Geração: 29
# Melhor Fitness: 0
# Geração: 30
# Melhor Fitness: 0
# Geração: 31
# Melhor Fitness: 0
# Geração: 32
# Melhor Fitness: 0
# Geração: 33
# Melhor Fitness: 0
# Geração: 34
# Melhor Fitness: 0
# Geração: 183
# Melhor Fitness: 0
# Geração: 184
# Melhor Fitness: 0
# Geração: 185
# Melhor Fitness: 0
# Geração: 186
# Melhor Fitness: 0
# Geração: 187
# Melhor Fitness: 0
# Geração: 188
# Melhor Fitness: 0
# Geração: 189
# Melhor Fitness: 0
# Geração: 190
# Melhor Fitness: 0
# Geração: 191
# Melhor Fitness: 0
# Geração: 192
# Melhor Fitness: 0
# Geração: 193
# Melhor Fitness: 0
# Geração: 194
# Melhor Fitness: 0
# Geração: 195
# Melhor Fitness: 0
# Geração: 196
# Melhor Fitness: 0
# Geração: 197
# Melhor Fitness: 0
# Geração: 198
# Melhor Fitness: 0
# Geração: 199
# Melhor Fitness: 0
# Geração: 200
# Melhor Fitness: 0
# Quantidade de funcionários por faixa salarial: [ 0 20 16 30  0]
# Fitness da melhor solução: 0
# Número total de funcionários contratados: 66
# Custo total da folha de pagamento: 208000

# %%
# Salário dos funcionários em diferentes faixas
fatores = {
    "salario1": 1000,
    "salario2": 2000,
    "salario3": 3000,
    "salario4": 4000,
    "salario5": 5000
}

# Lista de valores dos fatores
function_inputs = np.array(list(fatores.values()))
# Orçamento máximo
orcamento_maximo = 50000  # Pode ser ajustado conforme o caso real
# Quantidade desejada de funcionários
quantidade_desejada = 10

# Função que mede a quantidade de funcionarios e o orçamento máximo
def fitness_func(ga_instance, solution, solution_idx):
    total_funcionarios = np.sum(solution)
    total_custo = np.sum(solution * function_inputs)

    if total_custo > orcamento_maximo:
        return 0  # Penaliza soluções que ultrapassam o orçamento

    if total_funcionarios > quantidade_desejada:
        return 0  # Penaliza soluções que ultrapassam quantidade de funcionarios

    fitness = total_funcionarios / quantidade_desejada  # Maximiza o número de funcionários
    return fitness

num_generations = 200  # Número de gerações
num_parents_mating = 10  # Quantidade de pais selecionados

sol_per_pop = 20  # Tamanho da população
num_genes = len(function_inputs)

def on_generation(ga_instance):
    print(f"Geração: {ga_instance.generations_completed}")
    print(f"Melhor Fitness: {ga_instance.best_solution()[1]}")


# Configuração do Algoritmo Genético
ga_instance = pygad.GA(
    num_generations=num_generations,
    num_parents_mating=num_parents_mating,
    sol_per_pop=sol_per_pop,
    num_genes=num_genes,
    fitness_func=fitness_func,
    on_generation=on_generation,
    init_range_low=0,
    init_range_high=100,
    gene_type = int
)


# Executa o algoritmo
ga_instance.run()
ga_instance.plot_fitness()

# Exibe os melhores resultados
solution, solution_fitness, solution_idx = ga_instance.best_solution()
print(f"Quantidade de funcionários por faixa salarial: {solution}")
print(f"Fitness da melhor solução: {solution_fitness}")

total_funcionarios = np.sum(solution)
total_custo = np.sum(solution * function_inputs)
print(f"Número total de funcionários contratados: {int(total_funcionarios)}")
print(f"Custo total da folha de pagamento: {total_custo}")
# Out:
# Geração: 1
# Melhor Fitness: 0
# Geração: 2
# Melhor Fitness: 0
# Geração: 3
# Melhor Fitness: 0
# Geração: 4
# Melhor Fitness: 0
# Geração: 5
# Melhor Fitness: 0
# Geração: 6
# Melhor Fitness: 0
# Geração: 7
# Melhor Fitness: 0
# Geração: 8
# Melhor Fitness: 0
# Geração: 9
# Melhor Fitness: 0
# Geração: 10
# Melhor Fitness: 0
# Geração: 159
# Melhor Fitness: 0
# Geração: 160
# Melhor Fitness: 0
# Geração: 161
# Melhor Fitness: 0
# Geração: 162
# Melhor Fitness: 0
# Geração: 163
# Melhor Fitness: 0
# Geração: 164
# Melhor Fitness: 0
# Geração: 165
# Melhor Fitness: 0
# Geração: 166
# Melhor Fitness: 0
# Geração: 167
# Melhor Fitness: 0
# Geração: 168
# Melhor Fitness: 0
# Geração: 169
# Melhor Fitness: 0
# Geração: 170
# Melhor Fitness: 0
# Geração: 171
# Melhor Fitness: 0
# Geração: 172
# Melhor Fitness: 0
# Geração: 173
# Melhor Fitness: 0
# Geração: 174
# Melhor Fitness: 0
# Geração: 175
# Melhor Fitness: 0
# Geração: 176
# Melhor Fitness: 0
# Geração: 177
# Melhor Fitness: 0
# Geração: 178
# Melhor Fitness: 0
# Geração: 179
# Melhor Fitness: 0
# Geração: 180
# Melhor Fitness: 0
# Geração: 181
# Melhor Fitness: 0
# Geração: 182
# Melhor Fitness: 0
# Geração: 183
# Melhor Fitness: 0
# Geração: 184
# Melhor Fitness: 0
# Geração: 185
# Melhor Fitness: 0
# Geração: 186
# Melhor Fitness: 0
# Geração: 187
# Melhor Fitness: 0
# Geração: 188
# Melhor Fitness: 0
# Geração: 189
# Melhor Fitness: 0
# Geração: 190
# Melhor Fitness: 0
# Geração: 191
# Melhor Fitness: 0
# Geração: 192
# Melhor Fitness: 0
# Geração: 193
# Melhor Fitness: 0
# Geração: 194
# Melhor Fitness: 0
# Geração: 195
# Melhor Fitness: 0
# Geração: 196
# Melhor Fitness: 0
# Geração: 197
# Melhor Fitness: 0
# Geração: 198
# Melhor Fitness: 0
# Geração: 199
# Melhor Fitness: 0
# Geração: 200
# Melhor Fitness: 0
# Quantidade de funcionários por faixa salarial: [55  0 44 52 25]
# Fitness da melhor solução: 0
# Número total de funcionários contratados: 176
# Custo total da folha de pagamento: 520000

# %% [markdown]
# # **Referências**
#
#
#
# *   Notas da aula
# *   Documentação do Pygad

# %% [markdown]
# ---

# %%
#@title **Avaliação**
Resumo = 10 #@param {type:"slider", min:0, max:10, step:1}

Descricao_solucao = 7 #@param {type:"slider", min:0, max:10, step:1}

Implementacao = 9 #@param {type:"slider", min:0, max:10, step:1}

Resultados = 6 #@param {type:"slider", min:0, max:10, step:1}

Referencias = 7 #@param {type:"slider", min:0, max:10, step:1}

Geral = 7 #@param {type:"slider", min:0, max:10, step:1}

# %%
#@title **Nota Final**
nota = Resumo + Descricao_solucao + Implementacao + Resultados + Referencias + Geral

nota = nota / 6

print(f'Nota final do trabalho {nota :.1f}')

import numpy as np
import pandas as pd

alunos = pd.DataFrame()

lista_tia = []
lista_nome = []

for i in range(1,6):
  exec("if Aluno" + str(i) + " !='None':  lista = Aluno" + str(i) + ".split(','); lista_tia.append(lista[0]); lista_nome.append(lista[1].upper())")

alunos['tia'] = lista_tia
alunos['nome'] = lista_nome
alunos['nota'] = np.round(nota,1)
print()
display(alunos)
# Out:
# Nota final do trabalho 7.7
#         tia                        nome  nota
# 0  10364987   ENZO RYO MAEDA KANBAYASHI   7.7
